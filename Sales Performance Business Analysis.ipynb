# %% [markdown]
# # Sales performance business analysis

# %% [markdown]
# A data analysis unguided self project, datasets are obtained from Rakamin Virtual Experience Internship with Bank Muamalat
#
# - **Tools** : Jupyter Notebook, MySQL Workbench 8.0
# - **Languages** : SQL, Python

# %% [markdown]
# *This is a public portfolio version, i removed some credential details used for importing sql or python to jupyter notebook,
# so you are **unable reload this notebook**.
# But if you need to you can contact me*

# %% [markdown]
# ## Scenario
#
# As a BI analyst at PT Sejahtera Bersama, what can you propose to maintain sales or increase sales with the existing detailed transaction tables?

# %% [markdown]
# ## Importing SQL Connector

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %config SqlMagic.autopandas=True

# %%
# %%sql
#
# mysql://root:xxxxx@127.0.0.1:3306/data
#
#
# select * FROM customers

# %% [markdown]
# # Create Table

# %%
CREATE TABLE `data`.`orders` (
OrderID VARCHAR(255),
Date VARCHAR(30),
CustomerID VARCHAR(255),
ProdNumber VARCHAR(255),
Quantity INT NULL
);

# %%
CREATE TABLE `data`.`customers` (
CustomerID VARCHAR(255),
FirstName VARCHAR(100),
LastName VARCHAR(100),
CustomerEmail VARCHAR(255),
CustomerPhone VARCHAR (100),
CustomerAddress VARCHAR (255),
CustomerCity VARCHAR(255),
CustomerState VARCHAR (100),
CustomerZip INT
);

# %%
CREATE TABLE `data`.`product` (
ProdNumber VARCHAR(100),
ProdName VARCHAR(255),
Category INT,
Price DECIMAL(5,2)
);

# %%
CREATE TABLE `data`.`product_category` (
CategoryID VARCHAR(255),
CategoryName VARCHAR(255),
CategoryAbbreviation VARCHAR(255)
);

# %% [markdown]
# # Load Data to Table in Database

# %%
LOAD DATA INFILE "/Uploads/orders.csv"
INTO TABLE orders 
FIELDS TERMINATED BY ';' 
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS;
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 3339 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
LOAD DATA INFILE "/Uploads/customers.csv"
INTO TABLE customers 
FIELDS TERMINATED BY ';' 
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS;
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 2123 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
LOAD DATA INFILE "C/Uploads/product.csv"
INTO TABLE product 
FIELDS TERMINATED BY ';' 
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS;
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 70 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
LOAD DATA INFILE "/Uploads/product_category.csv"
INTO TABLE product_category 
FIELDS TERMINATED BY ';' 
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS;
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 7 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Begin using SQL

# %% [markdown]
# ## Take a look on the tables

# %%
# %%sql
#
# SELECT *
# FROM orders
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 3339 rows affected.
#      OrderID        Date CustomerID ProdNumber  Quantity
# 0          1  01/01/2020       1866      EB514         2
# 1          2  01/01/2020       1567      RS706         3
# 2          3  01/01/2020       2064      TV804         6
# 3          4  01/01/2020        287      DK203         1
# 4          5  01/01/2020        422      EB517         5
# ...      ...         ...        ...        ...       ...
# 3334    3335  31/12/2021        410      TV810         2
# 3335    3336  31/12/2021        520      RS707         5
# 3336    3337  31/12/2021        582      RK602         4
# 3337    3338  31/12/2021       1225      TV810         5
# 3338    3340  15/11/2021          5      EB508         2
#
# [3339 rows x 5 columns]

# %%
# %%sql
#
# # Alter datatype from string to datatype
#
# UPDATE `orders`
# SET `Date` = str_to_date( `Date`, '%d/%m/%Y' )

# %%
# %%sql
#
# ALTER TABLE orders modify Date DATE
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 3339 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
#
# SELECT *
# FROM orders
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 3339 rows affected.
#      OrderID        Date CustomerID ProdNumber  Quantity
# 0          1  2020-01-01       1866      EB514         2
# 1          2  2020-01-01       1567      RS706         3
# 2          3  2020-01-01       2064      TV804         6
# 3          4  2020-01-01        287      DK203         1
# 4          5  2020-01-01        422      EB517         5
# ...      ...         ...        ...        ...       ...
# 3334    3335  2021-12-31        410      TV810         2
# 3335    3336  2021-12-31        520      RS707         5
# 3336    3337  2021-12-31        582      RK602         4
# 3337    3338  2021-12-31       1225      TV810         5
# 3338    3340  2021-11-15          5      EB508         2
#
# [3339 rows x 5 columns]

# %%
# %%sql
#
# SELECT *
# FROM customers
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 2123 rows affected.
#      CustomerID FirstName    LastName  \
# 0             1    Grazia      Rasmus
# 1             2     Bunny      Trevan
# 2             3    Tracie    Grayston
# 3             4   Amerigo    Garrelts
# 4             5      Shea  Stronghill
# ...         ...       ...         ...
# 2118       2119    Tedman   Stockings
# 2119       2120    Jackie      Johnes
# 2120       2121   Dorella      Saxton
# 2121       2122     Rubia      Theuff
# 2122       2123   Morissa       Vasic
#
#                                           CustomerEmail   CustomerPhone  \
# 0             grasmusas@i2i.jp#mailto:grasmusas@i2i.jp#  (202) 577-2595
# 1     btrevanmj@wordpress.org#mailto:btrevanmj@wordp...    917-903-2827
# 2     tgrayston7k@pagesperso-orange.fr#mailto:tgrays...    404-868-2391
# 3     agarrelts6e@oaic.gov.au#mailto:agarrelts6e@oai...    415-190-3290
# 4     sstronghillc1@google.nl#mailto:sstronghillc1@g...    432-775-7828
# ...                                                 ...             ...
# 2118  tstockings94@opera.com#mailto:tstockings94@ope...    810-434-7886
# 2119          jjohnesgq@ca.gov#mailto:jjohnesgq@ca.gov#    941-491-1065
# 2120  dsaxton96@cornell.edu#mailto:dsaxton96@cornell...    404-165-3184
# 2121  rtheuffem@sfgate.com#mailto:rtheuffem@sfgate.com#    814-232-6220
# 2122  mvasiclp@sourceforge.net#mailto:mvasiclp@sourc...    727-419-6625
#
#               CustomerAddress      CustomerCity         CustomerState  \
# 0         628 Buhler Junction        Washington  District of Columbia
# 1            52 Cascade Drive           Jamaica              New York
# 2            672 Comanche Way           Atlanta               Georgia
# 3     8252 Village Green Hill     San Francisco            California
# 4               542 3rd Point           Midland                 Texas
# ...                       ...               ...                   ...
# 2118         406 Rigney Drive             Flint              Michigan
# 2119       19 Sunnyside Trail        North Port               Florida
# 2120  48 Prairieview Crossing            Duluth               Georgia
# 2121       70 Vernon Junction              Erie          Pennsylvania
# 2122          49 Susan Avenue  Saint Petersburg               Florida
#
#       CustomerZip
# 0           20029
# 1           11436
# 2           30343
# 3           94177
# 4           79705
# ...           ...
# 2118        48550
# 2119        34290
# 2120        30096
# 2121        16522
# 2122        33705
#
# [2123 rows x 9 columns]

# %%
# %%sql
#
# SELECT *
# FROM product
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 70 rows affected.
#    ProdNumber                         ProdName  Category  Price
# 0       BP101         All Eyes Drone Blueprint         1   9.99
# 1       BP102          Bsquare Robot Blueprint         1   8.99
# 2       BP104              Cat Robot Blueprint         1   4.99
# 3       BP105    Creature Robot Arms Blueprint         1  12.00
# 4       BP106       Hexacopter Drone Blueprint         1   8.99
# ..        ...                              ...       ...    ...
# 65      TV809        Understanding 3D Printing         7  42.99
# 66      TV810         Understanding Automation         7  44.95
# 67      TV811  Understanding Drone Regulations         7  27.50
# 68      TV812       Understanding Raspberry PI         7  28.99
# 69      TV813           Virtual Reality Basics         7  29.99
#
# [70 rows x 4 columns]

# %%
# %%sql
#
# SELECT *
# FROM product_category
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 7 rows affected.
#   CategoryID     CategoryName CategoryAbbreviation
# 0          1       Blueprints                 BP\r
# 1          2       Drone Kits                 DK\r
# 2          3           Drones                 DS\r
# 3          4           eBooks                 EB\r
# 4          5       Robot Kits                 RK\r
# 5          6           Robots                 RS\r
# 6          7  Training Videos                 TV\r

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### What is the time range for the orders?

# %%
# %%sql
#
# # What is the time range for the orders?
#
# SELECT
#     MIN(Date) as min,
#     MAX(Date) as max
# FROM
#     orders
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 1 rows affected.
#           min         max
# 0  2020-01-01  2021-12-31

# %% [markdown]
# ### How many total orders each year?

# %%
# %%sql
#
# # how many total orders each year?
#
# SELECT
#     YEAR(Date) AS year,
#     COUNT(OrderID) AS total_orders
# FROM
#     orders
# GROUP BY YEAR(Date)
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 2 rows affected.
#    year  total_orders
# 0  2020          1693
# 1  2021          1646

# %% [markdown]
# ### Which month and year has the most and the least orders?

# %%
# %%sql
#
# # Which month and year has the most and the least orders?
#
# WITH most_orders as
# (
# SELECT
#     YEAR(Date) AS year,
#     MONTH(Date) AS month,
#     COUNT(OrderID) AS num_of_orders
# FROM
#     orders
# GROUP BY YEAR(Date), MONTH(Date)
# ORDER BY year DESC, num_of_orders DESC
# ),
# rank_orders as
# (
#     SELECT
#         RANK () OVER (
#             PARTITION BY year
#             ORDER BY num_of_orders DESC) as order_rank,
#         year,
#         month,
#         num_of_orders
#     FROM
#         most_orders
# )
# SELECT *
# FROM rank_orders
# WHERE order_rank = 1 OR order_rank = 12
# ORDER BY order_rank
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 4 rows affected.
#    order_rank  year  month  num_of_orders
# 0           1  2020      5            162
# 1           1  2021      6            167
# 2          12  2020     11            117
# 3          12  2021      9            113

# %% [markdown]
# ### Which is the TOP 5 months in 2021 has the most orders

# %%
# %%sql
#
# # Which is the TOP 5 months in 2021 has the most orders
#
# SELECT
#     YEAR(Date) AS year,
#     MONTH(Date) AS month,
#     COUNT(OrderID) AS num_of_orders
# FROM
#     orders
# GROUP BY YEAR(Date), MONTH(Date)
# HAVING year = 2021
# ORDER BY num_of_orders DESC
# LIMIT 5
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 5 rows affected.
#    year  month  num_of_orders
# 0  2021      6            167
# 1  2021      1            157
# 2  2021      8            139
# 3  2021      4            138
# 4  2021      5            138

# %% [markdown]
# ### Which is the TOP 3 months in 2020 has the least orders

# %%
# %%sql
#
# # Which is the TOP 3 months in 2020 has the least orders
#
# SELECT
#     YEAR(Date) AS year,
#     MONTH(Date) AS month,
#     COUNT(OrderID) AS num_of_orders
# FROM
#     orders
# GROUP BY YEAR(Date), MONTH(Date)
# HAVING year = 2020
# ORDER BY num_of_orders
# LIMIT 3
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 3 rows affected.
#    year  month  num_of_orders
# 0  2020     11            117
# 1  2020      6            124
# 2  2020      8            128

# %% [markdown]
# ### Which customer has the most all-time orders?

# %%
# %%sql
#
# # Which customer has the most all-time orders?
#
# SELECT
#     DISTINCT(o.CustomerID) id,
#     c.FirstName,
#     c.LastName,
#     COUNT(o.OrderID) AS num_of_orders
# FROM
#     orders AS o
# LEFT JOIN
#     customers AS c
# ON
#     o.CustomerID = c.CustomerID
# GROUP BY
#     o.CustomerID
# ORDER BY num_of_orders DESC
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 1671 rows affected.
#         id  FirstName     LastName  num_of_orders
# 0     1851       Suki       Dixcee              7
# 1      628     Carlie         Pala              6
# 2     1202      Genni        Masic              6
# 3      496     Carole  Halliburton              6
# 4     1549     Harlan    Faulconer              6
# ...    ...        ...          ...            ...
# 1666  1664     Winnie      Shillam              1
# 1667   644        Ava      Fitzroy              1
# 1668   419  Alexandra        Stamp              1
# 1669  1439      Robby     Drinkale              1
# 1670   410      Nydia         Gyse              1
#
# [1671 rows x 4 columns]

# %% [markdown]
# ### Which customer has the most orders in 2021?

# %%
# %%sql
#
# # Which customer has the most orders in 2021?
#
# SELECT
#     DISTINCT(o.CustomerID) AS id,
#     o.Date AS date,
#     CONCAT(c.FirstName, " ", c.LastName) AS full_name,
#     COUNT(o.OrderID) AS orders_2021,
#     SUM(o.Quantity) AS item_quantity
# FROM
#     orders AS o
# LEFT JOIN
#     customers AS c
# ON
#     o.CustomerID = c.CustomerID
# WHERE Date LIKE '2021%'
# GROUP BY
#     o.CustomerID
# ORDER BY orders_2021 DESC
# LIMIT 5
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 5 rows affected.
#      id        date           full_name  orders_2021 item_quantity
# 0   496  2021-02-22  Carole Halliburton            5            13
# 1   504  2021-01-03      Derrek Shalloo            4            14
# 2   398  2021-01-01     Carma Threlfall            4            19
# 3  1902  2021-01-05    Corey McIlwreath            4            14
# 4  1243  2021-02-12         Marta Diben            4            18

# %% [markdown]
# ### Are there customers who has NO order?

# %%
# %%sql
#
# # Are there customers who has NO order?
#
# WITH cust_no_order AS (
# SELECT
#     DISTINCT c.CustomerID,
#     c.FirstName,
#     c.LastName,
#     o.OrderID,
#     CASE WHEN o.OrderID IS NULL THEN 'No Order' ELSE 'Ordered' END AS Status
# FROM
#     orders AS o
# RIGHT JOIN
#     customers AS c
# ON
#     o.CustomerID = c.CustomerID
# WHERE o.OrderID IS NULL
# )
# SELECT *
# FROM cust_no_order
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 452 rows affected.
#     CustomerID FirstName   LastName OrderID    Status
# 0            4   Amerigo   Garrelts    None  No Order
# 1           15  Davidson  Cramphorn    None  No Order
# 2           21    Oswell   Lissaman    None  No Order
# 3           23     Roddy      Dello    None  No Order
# 4           25   Donavon    Gosneye    None  No Order
# ..         ...       ...        ...     ...       ...
# 447       2106   Jordain     Clears    None  No Order
# 448       2112    Martha   Willoway    None  No Order
# 449       2117  Benjamen     Nyland    None  No Order
# 450       2118      Pren  Stockport    None  No Order
# 451       2122     Rubia     Theuff    None  No Order
#
# [452 rows x 5 columns]

# %% [markdown]
# ### How many customers has NO order?

# %%
# %%sql
#
# # How many customers has NO order?
#
# WITH cust_no_order AS
# (
# SELECT
#     DISTINCT c.CustomerID,
#     c.FirstName,
#     c.LastName,
#     o.OrderID
# FROM
#     orders AS o
# RIGHT JOIN
#     customers AS c
# ON
#     o.CustomerID = c.CustomerID
# WHERE o.OrderID IS NULL
# )
# SELECT COUNT(*) AS 'num of cust w/o order'
# FROM cust_no_order
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 1 rows affected.
#    num of cust w/o order
# 0                    452

# %% [markdown]
# ## Popular products

# %% [markdown]
# ### Which TOP 5 product name in each category sold the most?

# %%
# %%sql
#
# # Which TOP 5 product name in each category sold the most?
#
# WITH product_table as (
# SELECT
#     pc.CategoryID as category_id,
#     CategoryName as category,
#     p.ProdName as product_name,
#     SUM(o.Quantity) AS quantity_sold
# FROM
#     orders as o
# LEFT JOIN
#     product as p
# USING(ProdNumber)
# LEFT JOIN
#     product_category as pc
# ON
#     p.Category = pc.CategoryID
# GROUP BY
#     CategoryName, p.ProdName
# ORDER BY
#     category, quantity_sold DESC
# ),
# rank_sold as
# (
#     SELECT
#         DENSE_RANK () OVER (
#             PARTITION BY category
#             ORDER BY quantity_sold DESC) as q_rank,
#         category_id,
#         category,
#         product_name,
#         quantity_sold
#     FROM
#         product_table
# )
# SELECT *
#   FROM rank_sold
# WHERE q_rank <= 5
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 36 rows affected.
#     q_rank category_id         category                   product_name  \
# 0        1           1       Blueprints           Sleepy Eye Blueprint
# 1        2           1       Blueprints        Ladybug Robot Blueprint
# 2        3           1       Blueprints  Creature Robot Arms Blueprint
# 3        4           1       Blueprints         QuadroCopter Blueprint
# 4        5           1       Blueprints     Hexacopter Drone Blueprint
# 5        1           2       Drone Kits                       BYOD-500
# 6        2           2       Drone Kits                       BYOD-200
# 7        3           2       Drone Kits                       BYOD-220
# 8        4           2       Drone Kits                       BYOD-350
# 9        5           2       Drone Kits                       BYOD-550
# 10       1           3           Drones                   DTI-84 Drone
# 11       2           3           Drones                   DX-145 Drone
# 12       3           3           Drones                MICR-564K Drone
# 13       4           3           Drones                 DTD-7000 Drone
# 14       5           3           Drones                 DA-SA702 Drone
# 15       1           4           eBooks        Building Your Own Drone
# 16       2           4           eBooks                   Polar Robots
# 17       3           4           eBooks              Photograph Drones
# 18       4           4           eBooks                Delivery Drones
# 19       5           4           eBooks               Spherical Robots
# 20       1           5       Robot Kits                      BYOR-1000
# 21       2           5       Robot Kits                      BYOR-3000
# 22       3           5       Robot Kits                      BYOR-3535
# 23       4           5       Robot Kits                     BYOR-2640S
# 24       5           5       Robot Kits                      BYOR-4005
# 25       1           6           Robots                  RCB-889 Robot
# 26       2           6           Robots                 RXW-9807 Robot
# 27       3           6           Robots                 MICR-23K Robot
# 28       4           6           Robots                 RLK-9920 Robot
# 29       5           6           Robots                 RQTE-554 Robot
# 30       1           7  Training Videos               AI for Educators
# 31       2           7  Training Videos       Understanding Automation
# 32       2           7  Training Videos         Drone Video Techniques
# 33       3           7  Training Videos             Robotic Essentials
# 34       4           7  Training Videos         Industrial 3D Printing
# 35       5           7  Training Videos      Understanding 3D Printing
#
#    quantity_sold
# 0            312
# 1            187
# 2            182
# 3            175
# 4            162
# 5            203
# 6            191
# 7            186
# 8            172
# 9            169
# 10           231
# 11           192
# 12           173
# 13           171
# 14           170
# 15           210
# 16           204
# 17           199
# 18           181
# 19           176
# 20           198
# 21           196
# 22           186
# 23           164
# 24           158
# 25           208
# 26           190
# 27           175
# 28           173
# 29           170
# 30           211
# 31           183
# 32           183
# 33           181
# 34           172
# 35           169

# %% [markdown]
# ###  Which product category sold the most?

# %%
# %%sql
#
# # Which product category sold the most?
# SELECT
#     YEAR(Date) as year,
#     CategoryName,
#     SUM(o.Quantity) AS quantity_sold
# FROM
#     orders as o
# LEFT JOIN
#     product as p
# USING(ProdNumber)
# LEFT JOIN
#     product_category as pc
# ON
#     p.Category = pc.CategoryID
# GROUP BY
#     YEAR(Date), CategoryName
# ORDER BY
#     year DESC, quantity_sold DESC
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 14 rows affected.
#     year     CategoryName quantity_sold
# 0   2021           eBooks          1572
# 1   2021  Training Videos          1032
# 2   2021       Blueprints           751
# 3   2021       Drone Kits           736
# 4   2021           Drones           627
# 5   2021       Robot Kits           489
# 6   2021           Robots           476
# 7   2020           eBooks          1551
# 8   2020  Training Videos          1049
# 9   2020       Blueprints           867
# 10  2020       Drone Kits           779
# 11  2020           Drones           600
# 12  2020           Robots           577
# 13  2020       Robot Kits           548

# %% [markdown]
# ### Which e-Books about Robots sold the most?

# %%
# %%sql
#
# # Which e-Books about Robots sold the most?
#
# SELECT
#     CategoryName as category,
#     p.ProdName as product_name,
#     p.Price as price,
#     SUM(o.Quantity) AS quantity_sold
# FROM
#     orders as o
# LEFT JOIN
#     product as p
# USING(ProdNumber)
# LEFT JOIN
#     product_category as pc
# ON
#     p.Category = pc.CategoryID
# WHERE p.ProdName LIKE '%Robots'
# GROUP BY
#     CategoryName, p.ProdName
# HAVING
#     category = 'eBooks'
# ORDER BY
#     category, quantity_sold DESC
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 6 rows affected.
#   category        product_name  price quantity_sold
# 0   eBooks        Polar Robots  23.99           204
# 1   eBooks    Spherical Robots  16.75           176
# 2   eBooks    Cartesian Robots  12.99           175
# 3   eBooks        Delta Robots  16.99           158
# 4   eBooks        SCARA Robots  19.50           153
# 5   eBooks  Articulated Robots  23.99           141

# %% [markdown]
# ### Which product category gained the most all time revenue?

# %%
# %%sql
#
# # Which product category gained the most all time revenue?
# SELECT
#     CategoryName as category,
#     SUM(o.Quantity) as quantity,
#     p.Price as price_each,
#     (SUM(o.Quantity) * p.Price) as total_revenue
# FROM
#     orders as o
# LEFT JOIN
#     product as p
# USING(ProdNumber)
# LEFT JOIN
#     product_category as pc
# ON
#     p.Category = pc.CategoryID
# GROUP BY
#     CategoryName
# ORDER BY
#     total_revenue DESC
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 7 rows affected.
#           category quantity price_each total_revenue
# 0           Robots     1053     883.00     929799.00
# 1           Drones     1227     250.00     306750.00
# 2       Robot Kits     1037     189.00     195993.00
# 3       Drone Kits     1515      69.00     104535.00
# 4  Training Videos     2081      37.99      79057.19
# 5           eBooks     3123      23.99      74920.77
# 6       Blueprints     1618      12.00      19416.00

# %% [markdown]
# ### Which product category gained the most revenue each year?

# %%
# %%sql
#
# # Which product category gained the most revenue each year?
#
#
# SELECT
#     YEAR(o.Date) as year,
#     CategoryName as category,
#     SUM(Quantity) as quantity,
#     SUM(Quantity* Price) AS total_revenue
# FROM
#     orders as o
# LEFT JOIN
#     product as p
# USING(ProdNumber)
# JOIN
#     product_category as pc
# ON
#     p.Category = pc.CategoryID
# GROUP BY
#     year, CategoryName
# ORDER BY
#     year DESC, total_revenue DESC
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 14 rows affected.
#     year         category quantity total_revenue
# 0   2021           Robots      476     340670.00
# 1   2021           Drones      627     242584.00
# 2   2021       Robot Kits      489     101762.00
# 3   2021       Drone Kits      736      78209.10
# 4   2021  Training Videos     1032      40541.47
# 5   2021           eBooks     1572      30092.89
# 6   2021       Blueprints      751       7681.02
# 7   2020           Robots      577     402835.00
# 8   2020           Drones      600     234863.00
# 9   2020       Robot Kits      548     114675.00
# 10  2020       Drone Kits      779      83033.40
# 11  2020  Training Videos     1049      40174.68
# 12  2020           eBooks     1551      28875.52
# 13  2020       Blueprints      867       8753.49

# %% [markdown]
# ### How much total revenue per month?

# %%
# %%sql
#
# # Create a query to get revenue per month
#
# SELECT
#     YEAR(Date) as year,
#     MONTH(Date) as month,
#     SUM(Price * Quantity) as revenue_per_month
# FROM
# orders
# LEFT JOIN product
# USING(ProdNumber)
# GROUP BY year, month
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 24 rows affected.
#     year  month revenue_per_month
# 0   2020      1          87478.32
# 1   2020      2          74764.52
# 2   2020      3          74807.77
# 3   2020      4          66986.64
# 4   2020      5          79071.50
# 5   2020      6          64301.64
# 6   2020      7          76299.55
# 7   2020      8          85316.33
# 8   2020      9          85870.99
# 9   2020     10          74144.48
# 10  2020     11          71137.25
# 11  2020     12          73031.10
# 12  2021      1          78479.05
# 13  2021      2          72040.18
# 14  2021      3          57080.91
# 15  2021      4          71467.02
# 16  2021      5          68308.81
# 17  2021      6          95401.53
# 18  2021      7          56720.86
# 19  2021      8          76127.18
# 20  2021      9          78851.44
# 21  2021     10          52348.49
# 22  2021     11          62073.12
# 23  2021     12          72641.89

# %% [markdown]
# ### Top 3 products gained the biggest revenue in 2021, each month

# %%
# %%sql
#
# # Top 3 products gained the biggest revenue in 2021, each month
#
# WITH cte AS
# (
# SELECT
#     YEAR(Date) as year,
#     MONTH(Date) as month,
#     ProdName,
#     CategoryName,
#     quantity,
#     (Price * Quantity) as amount
# FROM orders o
# LEFT JOIN product p
# USING(ProdNumber)
# LEFT JOIN product_category pc
# ON p.Category = pc.CategoryID
# ),
# cte2 as
# (
#     SELECT year, month, ProdName, CategoryName, quantity, SUM(amount) as revenue_per_month
#     FROM cte
#     WHERE year = 2021
#     GROUP BY year, month, ProdName
#     ORDER BY year, month, revenue_per_month DESC
# ),
# cte3 as
# (
#     SELECT *,
#     DENSE_RANK() over(partition by month order by revenue_per_month desc) as rn
#     from cte2
# )
# select * from cte3
# where rn <=3
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 36 rows affected.
#     year  month         ProdName CategoryName  quantity revenue_per_month  rn
# 0   2021      1   MICR-23K Robot       Robots         6           9889.00   1
# 1   2021      1   RXW-9807 Robot       Robots         3           7787.00   2
# 2   2021      1     DC-304 Drone       Drones         2           6715.00   3
# 3   2021      2   RQTE-554 Robot       Robots         4          10260.00   1
# 4   2021      2   RXW-9807 Robot       Robots         5           7787.00   2
# 5   2021      2   MICR-23K Robot       Robots         4           7192.00   3
# 6   2021      3     DTI-84 Drone       Drones         4           5915.00   1
# 7   2021      3   RQTE-554 Robot       Robots         3           4788.00   2
# 8   2021      3  MICR-564K Drone       Drones         3           4491.00   3
# 9   2021      4     RWW-75 Robot       Robots         4           7947.00   1
# 10  2021      4   RQTE-554 Robot       Robots         4           5472.00   2
# 11  2021      4     DTI-84 Drone       Drones         5           5460.00   3
# 12  2021      5     RWW-75 Robot       Robots         4          12362.00   1
# 13  2021      5   RQTE-554 Robot       Robots         3           5472.00   2
# 14  2021      5   MICR-23K Robot       Robots         4           5394.00   3
# 15  2021      6   RQTE-554 Robot       Robots         5          10944.00   1
# 16  2021      6   MICR-23K Robot       Robots         3           8990.00   2
# 17  2021      6     RWW-75 Robot       Robots         5           7947.00   3
# 18  2021      7   RXW-9807 Robot       Robots         4           7787.00   1
# 19  2021      7     DTI-84 Drone       Drones         6           7735.00   2
# 20  2021      7   DTD-7000 Drone       Drones         3           6300.00   3
# 21  2021      8     RWW-75 Robot       Robots         6          13245.00   1
# 22  2021      8   MICR-23K Robot       Robots         5          12586.00   2
# 23  2021      8    RCB-889 Robot       Robots         3           8784.00   3
# 24  2021      9   MICR-23K Robot       Robots         4          12586.00   1
# 25  2021      9   RXW-9807 Robot       Robots         2          10183.00   2
# 26  2021      9   RLK-9920 Robot       Robots         6           9087.00   3
# 27  2021     10  MICR-564K Drone       Drones         4           7485.00   1
# 28  2021     10     DTI-84 Drone       Drones         5           5460.00   2
# 29  2021     10        BYOR-3535   Robot Kits         4           4950.00   3
# 30  2021     11   MICR-23K Robot       Robots         1           7192.00   1
# 31  2021     11    RCB-889 Robot       Robots         2           6039.00   2
# 32  2021     11  MICR-564K Drone       Drones         5           4990.00   3
# 33  2021     12   RQTE-554 Robot       Robots         6          10944.00   1
# 34  2021     12   DA-SA702 Drone       Drones         4           6384.00   2
# 35  2021     12     DX-145 Drone       Drones         4           5250.00   3

# %% [markdown]
# ## How is the company's YoY growth?

# %%
# %%sql
#
# WITH cte as
# ( SELECT
#     YEAR(Date) as year,
#     MONTH(Date) as month,
#     SUM(Price*Quantity) as revenue_per_month
# FROM orders o
# LEFT JOIN product p
# USING(ProdNumber)
# GROUP BY year
# ),
# cte2 as
# (
#     SELECT
#     year,
#     month,
#     revenue_per_month,
#     LAG(revenue_per_month) OVER ( ORDER BY year ) as revenue_last_year
#     FROM cte
# ),
# cte3 as
# (
#     SELECT *,
#     (revenue_last_year - revenue_per_month) as growth
#     FROM cte2)
# SELECT *
# FROM cte3
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 2 rows affected.
#    year  month revenue_per_month revenue_last_year    growth
# 0  2020      1         913210.09              None      None
# 1  2021      1         841540.48         913210.09  71669.61

# %% [markdown]
# ## YoY growth (per month)

# %%
# %%sql
#
# WITH cte as
# ( SELECT
#     YEAR(Date) as year,
#     MONTH(Date) as month,
#     SUM(Price*Quantity) as revenue_per_month
# FROM orders o
# LEFT JOIN product p
# USING(ProdNumber)
# GROUP BY year, month
# ),
# cte2 as
# (
#     SELECT *,
#     LAG(revenue_per_month) OVER ( ORDER BY year, month) AS revenue_last_month,
#     LAG(revenue_per_month) OVER (ORDER BY year, month) - revenue_per_month AS growth
#     FROM cte
# )
# SELECT * FROM cte2
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 24 rows affected.
#     year  month revenue_per_month revenue_last_month     growth
# 0   2020      1          87478.32               None       None
# 1   2020      2          74764.52           87478.32   12713.80
# 2   2020      3          74807.77           74764.52     -43.25
# 3   2020      4          66986.64           74807.77    7821.13
# 4   2020      5          79071.50           66986.64  -12084.86
# 5   2020      6          64301.64           79071.50   14769.86
# 6   2020      7          76299.55           64301.64  -11997.91
# 7   2020      8          85316.33           76299.55   -9016.78
# 8   2020      9          85870.99           85316.33    -554.66
# 9   2020     10          74144.48           85870.99   11726.51
# 10  2020     11          71137.25           74144.48    3007.23
# 11  2020     12          73031.10           71137.25   -1893.85
# 12  2021      1          78479.05           73031.10   -5447.95
# 13  2021      2          72040.18           78479.05    6438.87
# 14  2021      3          57080.91           72040.18   14959.27
# 15  2021      4          71467.02           57080.91  -14386.11
# 16  2021      5          68308.81           71467.02    3158.21
# 17  2021      6          95401.53           68308.81  -27092.72
# 18  2021      7          56720.86           95401.53   38680.67
# 19  2021      8          76127.18           56720.86  -19406.32
# 20  2021      9          78851.44           76127.18   -2724.26
# 21  2021     10          52348.49           78851.44   26502.95
# 22  2021     11          62073.12           52348.49   -9724.63
# 23  2021     12          72641.89           62073.12  -10568.77

# %% [markdown]
# ## Make a whole order details table for further analysis / visualization

# %%
# %%sql
#
# SELECT
#     o.CustomerID, o.OrderID, o.Date,
#     (CONCAT(FirstName, " ", LastName)) as FullName,
#     SUBSTR(CustomerEmail, 1, LOCATE('#', CustomerEmail) - 1) as Email,
#     CustomerPhone, CustomerAddress, CustomerCity, CustomerState, CustomerZip,
#     ProdNumber, ProdName, Price, Quantity,
#     (Price * Quantity) as Revenue,
#     CategoryID, CategoryName, CategoryAbbreviation as Abbr
# FROM orders as o
# LEFT JOIN
#     customers as c
# USING(CustomerID)
# LEFT JOIN
#     product as p
# USING(ProdNumber)
# LEFT JOIN
#     product_category as pc
# ON
#     p.Category = pc.CategoryID
# ORDER BY Date DESC
# Out:
#  * mysql://root:***@127.0.0.1:3306/data
# 3339 rows affected.
#      CustomerID OrderID        Date           FullName  \
# 0          1439    3333  2021-12-31     Robby Drinkale
# 1          1214    3332  2021-12-31       Joey Sumpner
# 2           625    3334  2021-12-31    Robinett Cossum
# 3           410    3335  2021-12-31         Nydia Gyse
# 4           520    3336  2021-12-31     Krystyna Coyte
# ...         ...     ...         ...                ...
# 3334        422       5  2020-01-01      Lucita Lesper
# 3335        954       6  2020-01-01  Llewellyn Fromont
# 3336       1866       1  2020-01-01     Farrand Vasler
# 3337       1567       2  2020-01-01    Terencio McKern
# 3338       2064       3  2020-01-01   Geordie Stiggers
#
#                              Email CustomerPhone       CustomerAddress  \
# 0           rdrinkale8z@tripod.com  209-943-7338    2203 Fordem Center
# 1         jsumpner5u@google.com.au  786-405-4171  420 Transport Center
# 2             rcossumba@devhub.com  314-377-5588     226 Karstens Hill
# 3     ngysehg@pagesperso-orange.fr  510-251-1787      4651 Boyd Circle
# 4            kcoytenm@bandcamp.com  215-676-8212          47 Spohn Way
# ...                            ...           ...                   ...
# 3334             llespercx@com.com  515-193-2721   393 Holmberg Center
# 3335              lfromonte9@de.vu  205-279-7028       14 Rowland Lane
# 3336         fvaslerqt@comsenz.com  601-786-0195      134 Melrose Pass
# 3337         tmckernot@tinyurl.com  832-987-8363          26 Muir Lane
# 3338    gstiggersdd@eventbrite.com  727-777-8163  11106 Cordelia Plaza
#
#           CustomerCity CustomerState  CustomerZip ProdNumber  \
# 0               Fresno    California        93721      TV807
# 1                Miami       Florida        33169      DS307
# 2          Saint Louis      Missouri        63169      DS302
# 3             Richmond    California        94807      TV810
# 4         Philadelphia  Pennsylvania        19093      RS707
# ...                ...           ...          ...        ...
# 3334        Des Moines          Iowa        50315      EB517
# 3335        Birmingham       Alabama        35244      EB519
# 3336           Jackson   Mississippi        39216      EB514
# 3337              Katy         Texas        77493      RS706
# 3338  Saint Petersburg       Florida        33737      TV804
#
#                       ProdName   Price  Quantity  Revenue CategoryID  \
# 0             Open Source Code   32.95         3    98.85          7
# 1              MICR-564K Drone  499.00         3  1497.00          3
# 2                 DC-304 Drone  395.00         5  1975.00          3
# 3     Understanding Automation   44.95         2    89.90          7
# 4               RXW-9807 Robot  599.00         5  2995.00          6
# ...                        ...     ...       ...      ...        ...
# 3334              SCARA Robots   19.50         5    97.50          4
# 3335          Spherical Robots   16.75         5    83.75          4
# 3336              Polar Robots   23.99         2    47.98          4
# 3337              RWW-75 Robot  883.00         3  2649.00          6
# 3338    Drone Video Techniques   37.99         6   227.94          7
#
#          CategoryName  Abbr
# 0     Training Videos  TV\r
# 1              Drones  DS\r
# 2              Drones  DS\r
# 3     Training Videos  TV\r
# 4              Robots  RS\r
# ...               ...   ...
# 3334           eBooks  EB\r
# 3335           eBooks  EB\r
# 3336           eBooks  EB\r
# 3337           Robots  RS\r
# 3338  Training Videos  TV\r
#
# [3339 rows x 18 columns]

# %% [markdown]
# Then, export the table by running the query with MySQL Workbench

# %% [markdown]
# # SQL to Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password=xxxxxx,
  database="data"
)

# %%
from sqlalchemy import create_engine

# %%
sqlEngine       = create_engine('mysql+pymysql://root:'xxxxxx@127.0.0.1:330x/data')
dbConnection    = sqlEngine.connect()

# %%
orders_df           = pd.read_sql("select * from data.orders", dbConnection);
orders_df.head()
# Out:
#   OrderID        Date CustomerID ProdNumber  Quantity
# 0       1  2020-01-01       1866      EB514         2
# 1       2  2020-01-01       1567      RS706         3
# 2       3  2020-01-01       2064      TV804         6
# 3       4  2020-01-01        287      DK203         1
# 4       5  2020-01-01        422      EB517         5

# %%
cust_df           = pd.read_sql("select * from data.customers", dbConnection);
cust_df.head()
# Out:
#   CustomerID FirstName    LastName  \
# 0          1    Grazia      Rasmus
# 1          2     Bunny      Trevan
# 2          3    Tracie    Grayston
# 3          4   Amerigo    Garrelts
# 4          5      Shea  Stronghill
#
#                                        CustomerEmail   CustomerPhone  \
# 0          grasmusas@i2i.jp#mailto:grasmusas@i2i.jp#  (202) 577-2595
# 1  btrevanmj@wordpress.org#mailto:btrevanmj@wordp...    917-903-2827
# 2  tgrayston7k@pagesperso-orange.fr#mailto:tgrays...    404-868-2391
# 3  agarrelts6e@oaic.gov.au#mailto:agarrelts6e@oai...    415-190-3290
# 4  sstronghillc1@google.nl#mailto:sstronghillc1@g...    432-775-7828
#
#            CustomerAddress   CustomerCity         CustomerState  CustomerZip
# 0      628 Buhler Junction     Washington  District of Columbia        20029
# 1         52 Cascade Drive        Jamaica              New York        11436
# 2         672 Comanche Way        Atlanta               Georgia        30343
# 3  8252 Village Green Hill  San Francisco            California        94177
# 4            542 3rd Point        Midland                 Texas        79705

# %%
product_df           = pd.read_sql("select * from data.product", dbConnection);
product_df.head()
# Out:
#   ProdNumber                       ProdName  Category  Price
# 0      BP101       All Eyes Drone Blueprint         1   9.99
# 1      BP102        Bsquare Robot Blueprint         1   8.99
# 2      BP104            Cat Robot Blueprint         1   4.99
# 3      BP105  Creature Robot Arms Blueprint         1  12.00
# 4      BP106     Hexacopter Drone Blueprint         1   8.99

# %%
prodcat_df           = pd.read_sql("select * from data.product_category", dbConnection);
product_df.head()
# Out:
#   ProdNumber                       ProdName  Category  Price
# 0      BP101       All Eyes Drone Blueprint         1   9.99
# 1      BP102        Bsquare Robot Blueprint         1   8.99
# 2      BP104            Cat Robot Blueprint         1   4.99
# 3      BP105  Creature Robot Arms Blueprint         1  12.00
# 4      BP106     Hexacopter Drone Blueprint         1   8.99

# %%
complete_df = pd.read_csv('/Uploads/customer order complete data.csv')

complete_df.head()
# Out:
#    CustomerID  OrderID        Date         FullName  \
# 0        1439     3333  2021-12-31   Robby Drinkale
# 1        1214     3332  2021-12-31     Joey Sumpner
# 2         625     3334  2021-12-31  Robinett Cossum
# 3         410     3335  2021-12-31       Nydia Gyse
# 4         520     3336  2021-12-31   Krystyna Coyte
#
#                           Email CustomerPhone       CustomerAddress  \
# 0        rdrinkale8z@tripod.com  209-943-7338    2203 Fordem Center
# 1      jsumpner5u@google.com.au  786-405-4171  420 Transport Center
# 2          rcossumba@devhub.com  314-377-5588     226 Karstens Hill
# 3  ngysehg@pagesperso-orange.fr  510-251-1787      4651 Boyd Circle
# 4         kcoytenm@bandcamp.com  215-676-8212          47 Spohn Way
#
#    CustomerCity CustomerState  CustomerZip ProdNumber  \
# 0        Fresno    California        93721      TV807
# 1         Miami       Florida        33169      DS307
# 2   Saint Louis      Missouri        63169      DS302
# 3      Richmond    California        94807      TV810
# 4  Philadelphia  Pennsylvania        19093      RS707
#
#                    ProdName   Price  Quantity  Revenue  CategoryID  \
# 0          Open Source Code   32.95         3    98.85           7
# 1           MICR-564K Drone  499.00         3  1497.00           3
# 2              DC-304 Drone  395.00         5  1975.00           3
# 3  Understanding Automation   44.95         2    89.90           7
# 4            RXW-9807 Robot  599.00         5  2995.00           6
#
#       CategoryName  Abbr
# 0  Training Videos  TV\r
# 1           Drones  DS\r
# 2           Drones  DS\r
# 3  Training Videos  TV\r
# 4           Robots  RS\r

# %% [markdown]
# # Visualization

# %%
complete_df['Month'] = pd.to_datetime(complete_df['Date']).dt.month
complete_df['Year'] = pd.to_datetime(complete_df['Date']).dt.year

# %%
complete_df.head()
# Out:
#    CustomerID  OrderID        Date         FullName  \
# 0        1439     3333  2021-12-31   Robby Drinkale
# 1        1214     3332  2021-12-31     Joey Sumpner
# 2         625     3334  2021-12-31  Robinett Cossum
# 3         410     3335  2021-12-31       Nydia Gyse
# 4         520     3336  2021-12-31   Krystyna Coyte
#
#                           Email CustomerPhone       CustomerAddress  \
# 0        rdrinkale8z@tripod.com  209-943-7338    2203 Fordem Center
# 1      jsumpner5u@google.com.au  786-405-4171  420 Transport Center
# 2          rcossumba@devhub.com  314-377-5588     226 Karstens Hill
# 3  ngysehg@pagesperso-orange.fr  510-251-1787      4651 Boyd Circle
# 4         kcoytenm@bandcamp.com  215-676-8212          47 Spohn Way
#
#    CustomerCity CustomerState  CustomerZip ProdNumber  \
# 0        Fresno    California        93721      TV807
# 1         Miami       Florida        33169      DS307
# 2   Saint Louis      Missouri        63169      DS302
# 3      Richmond    California        94807      TV810
# 4  Philadelphia  Pennsylvania        19093      RS707
#
#                    ProdName   Price  Quantity  Revenue  CategoryID  \
# 0          Open Source Code   32.95         3    98.85           7
# 1           MICR-564K Drone  499.00         3  1497.00           3
# 2              DC-304 Drone  395.00         5  1975.00           3
# 3  Understanding Automation   44.95         2    89.90           7
# 4            RXW-9807 Robot  599.00         5  2995.00           6
#
#       CategoryName  Abbr    Month
# 0  Training Videos  TV\r  2021-12
# 1           Drones  DS\r  2021-12
# 2           Drones  DS\r  2021-12
# 3  Training Videos  TV\r  2021-12
# 4           Robots  RS\r  2021-12

# %% [markdown]
# ### Quantity sold per category

# %%
print(complete_df['CategoryName'].value_counts())

sns.countplot(data=complete_df, y="CategoryName", order= complete_df['CategoryName'].value_counts().index)
plt.show()
# Out:
# eBooks             891
# Training Videos    615
# Blueprints         455
# Drone Kits         433
# Drones             352
# Robot Kits         302
# Robots             291
# Name: CategoryName, dtype: int64

# %% [markdown]
# ### Company revenue per month

# %%
rev1 = complete_df.groupby(['Year', 'Month']).agg({'Revenue': 'sum'}).reset_index()
sns.lineplot(data=rev1, x="Month", y="Revenue", hue="Year", palette="Set2")
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Revenue'>

# %% [markdown]
# ### Revenue per product category

# %%
rev1 = complete_df.groupby(['Year', 'CategoryName']).agg({'Revenue': 'sum'}).reset_index()
plt.subplots(figsize=(10,4))


sns.lineplot(data=rev1, x="CategoryName", y="Revenue", hue="Year", palette="Set2")
# Out:
# <AxesSubplot:xlabel='CategoryName', ylabel='Revenue'>

# %% [markdown]
# ### Quantity sold per category

# %%
cat1 = complete_df.groupby(['Year', 'Month', 'CategoryName']).agg({'Quantity': 'sum'}).reset_index()
plt.subplots(figsize=(10,5))


sns.barplot(x='CategoryName', y='Quantity', hue='Year', data=cat1, palette='Set2')
# Out:
# <AxesSubplot:xlabel='CategoryName', ylabel='Quantity'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# - The company experienced a decrease in 2021 revenue from 2020
# - Product sales trend in 2021 decreased compared to 2020
# - The product category that customers are most interested in is eBooks
# - The product category that provides the most revenue for the company is Robots, while eBooks is one of the product categories that generates the lowest income even though it sells the most.

# %% [markdown]
# # Recommendation

# %% [markdown]
# PT Sejahtera Bersama should consider:
# - Increase the price of eBooks so that their revenue increases, or
# - Reduce the price of Robots so that customers are interested in buying Robot products
# - Set feasible sales targets to drive company growth
#
# Of course these are done with prior market research and further analysis.
# Other than price changes, company must carry out even more promotion of Robot or other products which sales are less than other products
